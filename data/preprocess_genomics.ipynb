# %%
import os
import sys
from pathlib import Path
import yaml
import pickle
import argparse
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lifelines.utils import concordance_index
from lifelines import CoxPHFitter

from coxkan import CoxKAN
from coxkan.utils import bootstrap_metric, set_seed

SEED = set_seed(42)

# %%
### Reusable functions for the notebook

def true_cindex(df):
    global sim_config, duration_col, event_col, covariates
    lph = sim_config['log_partial_hazard'](**df[covariates])
    return concordance_index(df[duration_col], -lph, df[event_col])

def cph_cindex(df):
    global cph
    return cph.score(df, scoring_method='concordance_index')

def cph_reg_cindex(df):
    global cph_reg
    return cph_reg.score(df, scoring_method='concordance_index')

def cph_formula(cph):
    coefficients = cph.params_
    terms = []
    for covariate, coefficient in coefficients.items():
        term = f"{coefficient:.4f} * {covariate}"
        terms.append(term)
    expression = " + ".join(terms)
    return expression

# %%
# open CoxKAN/data/TCGA/genomics/{name}_genomics.csv
name = 'LUAD'

genomics_df = pd.read_csv(f'./TCGA/genomics/{name}_genomics.csv')
genomic_labels_train_df = pd.read_csv(f'./TCGA/{name}_labels/train.csv')
genomic_labels_test_df = pd.read_csv(f'./TCGA/{name}_labels/test.csv')

#concat train and test labels
genomic_labels_df = pd.concat([genomic_labels_train_df, genomic_labels_test_df])

genomic_labels_df = genomic_labels_df[['case_id', 'dss_cr_survival_days', 'dss_cr_censorship']]

# fill all empty dss_cr_censorship with zeros
genomic_labels_df['dss_cr_censorship'] = genomic_labels_df['dss_cr_censorship'].fillna(0)

#get rid of appended string after the final '_' in the sample column
genomics_df['sample'] = genomics_df['sample'].str.split('-').str[:-1].str.join('-')

# merge the genomic data with the labels based on the sample column in genomics_df and case_id column in genomic_labels_df
genomics_df = pd.merge(genomics_df, genomic_labels_df, left_on='sample', right_on='case_id', how='inner')

# drop any column beginning with 'Unnamed'
genomics_df = genomics_df.loc[:, ~genomics_df.columns.str.contains('^Unnamed')]

#same for 'case_id'
genomics_df = genomics_df.loc[:, ~genomics_df.columns.str.contains('^case_id')]

print(f"Genomics dataframe shape: {genomics_df.shape}")
# Out:
# Genomics dataframe shape: (538, 4171)

# %%
correlations = {}

#for each non-duration and non-event column, calculate the univariate CoxPH p-value
for col in genomics_df.columns:
    if 'sample' in col:
        continue
    if col not in ['dss_cr_survival_days', 'dss_cr_censorship']:
        train_df_univariate = genomics_df[['dss_cr_survival_days', 'dss_cr_censorship', col]].copy()
        
        # drop cols with nans
        train_df_univariate = train_df_univariate.dropna()
        # fit the CoxPH model
        cph = CoxPHFitter()
        try:
            cph.fit(train_df_univariate, duration_col='dss_cr_survival_days', event_col='dss_cr_censorship', formula=f"{col}")
            p_value = cph.summary['p'].values[0]
            
            # append to the list
            correlations[col] = p_value
        except Exception as e:
            p_value = np.inf
            correlations[col] = p_value
            print(f"Error fitting CoxPH model for {col}: {e}")
        
        # get the p-value

        
        print(f"Univariate CoxPH p-value for {col}: {p_value}")

        
# filter the genomics_df to only include features with p-values < 0.05
filtered_genomics_df = genomics_df.copy()
for col, p_value in correlations.items():
    if p_value >= 0.05:
        filtered_genomics_df = filtered_genomics_df.drop(columns=[col])

print(f"Filtered genomics dataframe shape: {filtered_genomics_df.shape}")
# Out:
# Univariate CoxPH p-value for A2M: 0.22046914373131415
# Univariate CoxPH p-value for AAAS: 0.1389791676474925
# Univariate CoxPH p-value for AADAT: 0.4838511007107471
# Univariate CoxPH p-value for ABAT: 0.7352437203502353
# Univariate CoxPH p-value for ABCA1: 0.00833664866570198
# Univariate CoxPH p-value for ABCA2: 1.6860600986309297e-05
# Univariate CoxPH p-value for ABCA3: 0.7969088491075322
# Univariate CoxPH p-value for ABCA4: 0.0033906422700804902
# Univariate CoxPH p-value for ABCA5: 0.5189853150987529
# Univariate CoxPH p-value for ABCA6: 0.10509937482479388
# Univariate CoxPH p-value for ABCA8: 0.9400792306096518
# Univariate CoxPH p-value for ABCA9: 0.03004297364580446
# Univariate CoxPH p-value for ABCB1: 0.3409629006453053
# Univariate CoxPH p-value for ABCB11: 0.22883029880682343
# Univariate CoxPH p-value for ABCB4: 0.4558846231027003
# Univariate CoxPH p-value for ABCB6: 0.14274511106217538
# Univariate CoxPH p-value for ABCB7: 0.6824307436693885
# Univariate CoxPH p-value for ABCB8: 0.0631403136325118
# Univariate CoxPH p-value for ABCB9: 0.001679042889834672
# Univariate CoxPH p-value for ABCC1: 0.03438123164906449
# Univariate CoxPH p-value for ABCC2: 0.7199733666358457
# Univariate CoxPH p-value for ABCC3: 0.06642734888011535
# Univariate CoxPH p-value for ABCC4: 0.3217251859074461
# Univariate CoxPH p-value for ABCC5: 0.0005097791877407225
# Univariate CoxPH p-value for ABCC8: 0.09975937353488173
# Univariate CoxPH p-value for ABCD1: 0.6545893633239077
# Univariate CoxPH p-value for ABCD2: 0.04477729612231876
# Univariate CoxPH p-value for ABCD3: 0.28229073479247374
# Univariate CoxPH p-value for ABCE1: 0.7765675526250674
# Univariate CoxPH p-value for ABCF2: 0.787885321314804
# Univariate CoxPH p-value for ABCG2: 0.07571730311960045
# Univariate CoxPH p-value for ABCG4: 0.013441385624487594
# Univariate CoxPH p-value for ABCG8: 0.7788702929505106
# Univariate CoxPH p-value for ABHD2: 0.260103214798823
# Univariate CoxPH p-value for ABHD4: 0.02145573307380879
# Univariate CoxPH p-value for ABHD6: 0.029007150429217386
# Univariate CoxPH p-value for ABI1: 0.23274518316596018
# Univariate CoxPH p-value for ABI3BP: 0.8405396411826137
# Univariate CoxPH p-value for ABL1: 0.007924283581916967
# Univariate CoxPH p-value for ABLIM1: 0.4453789678773451
# Univariate CoxPH p-value for ABR: 0.3332959227273901
# Univariate CoxPH p-value for ACAA1: 0.01687923792369827
# Univariate CoxPH p-value for ACAA2: 0.0449724573633378
# Univariate CoxPH p-value for ACACA: 0.1420132944084754
# Univariate CoxPH p-value for ACADL: 0.04427316502913266
# Univariate CoxPH p-value for ACADM: 0.37273980378425275
# Univariate CoxPH p-value for ACADS: 0.001169627734326187
# Univariate CoxPH p-value for ACADSB: 0.352882269802243
# Univariate CoxPH p-value for ACADVL: 0.8736569605274819
# Univariate CoxPH p-value for ACAT1: 0.012038239393378137
# Univariate CoxPH p-value for ACAT2: 0.002592711765870137
# Univariate CoxPH p-value for ACE: 0.5566302055254752
# Univariate CoxPH p-value for ACHE: 0.03865695838636967
# Univariate CoxPH p-value for ACLY: 0.025455776354058404
# Univariate CoxPH p-value for ACO2: 0.6903107102560655
# Univariate CoxPH p-value for ACOT2: 0.004324778999380361
# Univariate CoxPH p-value for ACOT8: 0.0025269168531506262
# Univariate CoxPH p-value for ACOX1: 0.1688743836510912
# Univariate CoxPH p-value for ACOX2: 0.7228572692686535
# Univariate CoxPH p-value for ACOX3: 0.024494418325154678
# Univariate CoxPH p-value for ACP1: 0.03924714651556682
# Univariate CoxPH p-value for ACP2: 0.2576111143708876
# Univariate CoxPH p-value for ACP5: 0.2407390171048281
# Univariate CoxPH p-value for ACRBP: 0.16349773682725663
# Univariate CoxPH p-value for ACRV1: 0.9891539896480865
# Univariate CoxPH p-value for ACSL1: 0.02962631270456715
# Univariate CoxPH p-value for ACSL3: 0.6529465324136365
# Univariate CoxPH p-value for ACSL4: 0.9927809158800769
# Univariate CoxPH p-value for ACSL5: 0.19055589939312245
# Univariate CoxPH p-value for ACSL6: 0.09075712775532548
# Univariate CoxPH p-value for ACSM1: 0.6111102439130969
# Univariate CoxPH p-value for ACSM3: 0.5275644682650471
# Univariate CoxPH p-value for ACSS1: 0.9069475345101359
# Univariate CoxPH p-value for ACSS2: 0.0004077367484637894
# Univariate CoxPH p-value for ACTA1: 0.04863626915515927
# Univariate CoxPH p-value for ACTA2: 0.8650076478124242
# Univariate CoxPH p-value for ACTB: 0.016239347585130726
# Univariate CoxPH p-value for ACTC1: 0.257849926831325
# Univariate CoxPH p-value for ACTG1: 0.5990981185481297
# Univariate CoxPH p-value for ACTG2: 0.8106165131744028
# Univariate CoxPH p-value for ACTL7B: 0.020709937968382355
# Univariate CoxPH p-value for ACTN1: 0.21242430603123913
# Univariate CoxPH p-value for ACTN2: 0.8095390306134221
# Univariate CoxPH p-value for ACTN3: 0.0037708988185058035
# Univariate CoxPH p-value for ACTN4: 0.9086959831260419
# Univariate CoxPH p-value for ACTR2: 0.41278050387443777
# Univariate CoxPH p-value for ACTR3: 0.07439216767413079
# Univariate CoxPH p-value for ACVR1: 0.5686151461466928
# Univariate CoxPH p-value for ACVR1B: 0.034642413050741436
# Univariate CoxPH p-value for ACVR2A: 0.32600293881052456
# Univariate CoxPH p-value for ACVRL1: 0.27170667601014015
# Univariate CoxPH p-value for ADA: 0.6595089241088645
# Univariate CoxPH p-value for ADAD1: 0.7219667004408146
# Univariate CoxPH p-value for ADAM10: 0.009355148269397899
# Univariate CoxPH p-value for ADAM12: 0.005263828947023117
# Univariate CoxPH p-value for ADAM15: 0.7888046539456628
# Univariate CoxPH p-value for ADAM17: 0.32200079606948373
# Univariate CoxPH p-value for ADAM19: 0.0017447714345414206
# Univariate CoxPH p-value for ADAM2: 0.5659737081142222
# Univariate CoxPH p-value for ADAM23: 0.27670377472654206
# Univariate CoxPH p-value for ADAM8: 0.027958373525372344
# Univariate CoxPH p-value for ADAM9: 0.4332565450358211
# Univariate CoxPH p-value for ADAMDEC1: 0.06606881795462179
# Univariate CoxPH p-value for ADAMTS1: 0.6232124394243128
# Univariate CoxPH p-value for ADAMTS5: 0.32574707247356066
# Univariate CoxPH p-value for ADAR: 0.0017054646041487493
# Univariate CoxPH p-value for ADCY1: 0.10105816912739296
# Univariate CoxPH p-value for ADCY2: 0.6735563359817508
# Univariate CoxPH p-value for ADCY6: 7.887740825948842e-06
# Univariate CoxPH p-value for ADCY9: 0.44994580304677023
# Univariate CoxPH p-value for ADCYAP1: 0.23396913790752003
# Univariate CoxPH p-value for ADD1: 0.7455007480732676
# Univariate CoxPH p-value for ADD2: 0.5133806139642636
# Univariate CoxPH p-value for ADD3: 0.02487049780152397
# Univariate CoxPH p-value for ADH1C: 0.03389249619122215
# Univariate CoxPH p-value for ADH4: 0.17755045032175487
# Univariate CoxPH p-value for ADH5: 0.002120313743632348
# Univariate CoxPH p-value for ADH7: 0.042308459536511224
# Univariate CoxPH p-value for ADIG: 0.7430728962245521
# Univariate CoxPH p-value for ADIPOQ: 0.5485940968131808
# Univariate CoxPH p-value for ADIPOR1: 0.05296871306460217
# Univariate CoxPH p-value for ADIPOR2: 0.9466077605640554
# Univariate CoxPH p-value for ADM: 0.8176572522244699
# Univariate CoxPH p-value for ADORA2B: 0.23458407659618186
# Univariate CoxPH p-value for ADRA1B: 0.3174212994207055
# Univariate CoxPH p-value for ADRA2B: 0.985582059902653
# Univariate CoxPH p-value for ADRA2C: 0.1838699362554306
# Univariate CoxPH p-value for ADRM1: 0.09279649676352275
# Univariate CoxPH p-value for ADSL: 0.032205588659342824
# Univariate CoxPH p-value for AEBP1: 0.0323048846272641
# Univariate CoxPH p-value for AEN: 0.40662781927558833
# Univariate CoxPH p-value for AFAP1L2: 0.0012682940099063044
# Univariate CoxPH p-value for AFF1: 7.287827339758687e-05
# Univariate CoxPH p-value for AFG3L2: 0.1426001050195195
# Univariate CoxPH p-value for AGER: 0.519209255990662
# Univariate CoxPH p-value for AGFG1: 0.9504661161321817
# Univariate CoxPH p-value for AGGF1: 0.9377482938627297
# Univariate CoxPH p-value for AGL: 0.13056607943266235
# Univariate CoxPH p-value for AGPAT3: 0.773516864609392
# Univariate CoxPH p-value for AGPAT4: 0.4362653572497672
# Univariate CoxPH p-value for AGR2: 0.20234770866143081
# Univariate CoxPH p-value for AGRN: 0.002672384497622788
# Univariate CoxPH p-value for AGXT: 0.7455096245308802
# Univariate CoxPH p-value for AHCY: 0.027394536918412236
# Univariate CoxPH p-value for AHNAK: 0.021578434104904946
# Univariate CoxPH p-value for AHR: 0.1624544538359823
# Univariate CoxPH p-value for AHSP: 0.3659711838274641
# Univariate CoxPH p-value for AIFM1: 0.7333914466584601
# Univariate CoxPH p-value for AIFM3: 0.7667532997941867
# Univariate CoxPH p-value for AIMP2: 0.41357085152281625
# Univariate CoxPH p-value for AK1: 0.02529445911984975
# Univariate CoxPH p-value for AK2: 0.0059940453467515155
# Univariate CoxPH p-value for AK3: 0.5855016723848729
# Univariate CoxPH p-value for AKAP10: 0.0019487612244451767
# Univariate CoxPH p-value for AKAP12: 0.8107345585482456
# Univariate CoxPH p-value for AKAP13: 0.18276255096787117
# Univariate CoxPH p-value for AKAP4: 0.6212825790627191
# Univariate CoxPH p-value for AKAP7: 0.04070588813479613
# Univariate CoxPH p-value for AKR1A1: 0.0038034145436766716
# Univariate CoxPH p-value for AKR1B10: 0.2243275715773654
# Univariate CoxPH p-value for AKR1C2: 0.0006333295444165384
# Univariate CoxPH p-value for AKR1C3: 0.007418880962953674
# Univariate CoxPH p-value for AKR1D1: 0.1266576000639785
# Univariate CoxPH p-value for AKT1: 0.08508941419763714
# Univariate CoxPH p-value for AKT1S1: 0.7243724827390715
# Univariate CoxPH p-value for AKT2: 0.9699621673385505
# Univariate CoxPH p-value for AKT3: 0.5042922589348033
# Univariate CoxPH p-value for ALAD: 0.9805068259950469
# Univariate CoxPH p-value for ALAS1: 0.8111775948237898
# Univariate CoxPH p-value for ALAS2: 0.13631790901858706
# Univariate CoxPH p-value for ALB: 0.14098099378522647
# Univariate CoxPH p-value for ALCAM: 0.3760015203792265
# Univariate CoxPH p-value for ALDH18A1: 0.30983490737512676
# Univariate CoxPH p-value for ALDH1A1: 0.2275131187899431
# Univariate CoxPH p-value for ALDH1A2: 0.04380942085515063
# Univariate CoxPH p-value for ALDH1A3: 0.0009357546824766556
# Univariate CoxPH p-value for ALDH1L1: 0.004295945152397565
# Univariate CoxPH p-value for ALDH2: 0.002976301382220026
# Univariate CoxPH p-value for ALDH3A1: 0.016314633227492485
# Univariate CoxPH p-value for ALDH3A2: 0.2813575090020498
# Univariate CoxPH p-value for ALDH3B1: 0.2831374781632325
# Univariate CoxPH p-value for ALDH6A1: 0.8453331718338011
# Univariate CoxPH p-value for ALDH7A1: 1.211925086225254e-05
# Univariate CoxPH p-value for ALDH8A1: 0.04453382836670995
# Univariate CoxPH p-value for ALDH9A1: 0.0006638837078312512
# Univariate CoxPH p-value for ALDOA: 0.15001220176478794
# Univariate CoxPH p-value for ALDOB: 0.5874029489209938
# Univariate CoxPH p-value for ALDOC: 0.9243038909813098
# Univariate CoxPH p-value for ALG1: 0.0365866208294824
# Univariate CoxPH p-value for ALMS1: 0.031187143979615643
# Univariate CoxPH p-value for ALOX12B: 0.8600128227801144
# Univariate CoxPH p-value for ALOX15: 0.20475570915088706
# Univariate CoxPH p-value for ALOX15B: 0.49832869794209556
# Univariate CoxPH p-value for ALS2: 0.16831232556240378
# Univariate CoxPH p-value for AMACR: 0.8668794586018996
# Univariate CoxPH p-value for AMBN: 0.2259638162468224
# Univariate CoxPH p-value for AMD1: 0.3126163887077186
# Univariate CoxPH p-value for AMFR: 0.0016489667524337331
# Univariate CoxPH p-value for AMH: 0.0012990186957326083
# Univariate CoxPH p-value for AMIGO1: 0.4557224289920533
# Univariate CoxPH p-value for AMIGO2: 0.16493695525472038
# Univariate CoxPH p-value for AMMECR1: 0.029475379961118268
# Univariate CoxPH p-value for AMOT: 0.4463816387982463
# Univariate CoxPH p-value for AMPD3: 0.06768575668610576
# Univariate CoxPH p-value for AMPH: 0.7755145172640782
# Univariate CoxPH p-value for ANG: 0.0032061235377327997
# Univariate CoxPH p-value for ANGPT1: 0.5966352142865157
# Univariate CoxPH p-value for ANGPTL3: 0.6011246110758123
# Univariate CoxPH p-value for ANGPTL4: 0.4272749260245423
# Univariate CoxPH p-value for ANK1: 0.9284846803478645
# Univariate CoxPH p-value for ANKH: 0.018842772593505936
# Univariate CoxPH p-value for ANKRA2: 0.7668907577465283
# Univariate CoxPH p-value for ANKRD2: 0.7444334795790692
# Univariate CoxPH p-value for ANKZF1: 0.007474289468211791
# Univariate CoxPH p-value for ANLN: 0.003843167029210537
# Univariate CoxPH p-value for ANO1: 0.006945392184380123
# Univariate CoxPH p-value for ANP32E: 0.6700452027027377
# Univariate CoxPH p-value for ANPEP: 0.2903968682710499
# Univariate CoxPH p-value for ANTXR2: 0.008959764528174765
# Univariate CoxPH p-value for ANXA1: 0.2559205283908091
# Univariate CoxPH p-value for ANXA10: 0.1383996566776362
# Univariate CoxPH p-value for ANXA13: 0.00709974804475226
# Univariate CoxPH p-value for ANXA2: 0.1520411209995501
# Univariate CoxPH p-value for ANXA4: 0.06085905900993567
# Univariate CoxPH p-value for ANXA5: 0.04559215062825969
# Univariate CoxPH p-value for ANXA9: 0.15492959974489998
# Univariate CoxPH p-value for AOC3: 1.0
# Univariate CoxPH p-value for AOX1: 0.9007650540272986
# Univariate CoxPH p-value for AP1G1: 0.8266431106660543
# Univariate CoxPH p-value for AP2B1: 0.044386228779350057
# Univariate CoxPH p-value for AP2M1: 0.5158369106670273
# Univariate CoxPH p-value for AP2S1: 0.00012883899058820886
# Univariate CoxPH p-value for AP3B1: 0.2719342234908633
# Univariate CoxPH p-value for AP3S1: 0.26823457380234517
# Univariate CoxPH p-value for AP4B1: 0.0012917192768544244
# Univariate CoxPH p-value for APAF1: 1.9826654501832346e-05
# Univariate CoxPH p-value for APBB1: 0.4737061550633147
# Univariate CoxPH p-value for APBB2: 0.2500396240101157
# Univariate CoxPH p-value for APC: 0.11534363645737862
# Univariate CoxPH p-value for APEX1: 0.32973265170564015
# Univariate CoxPH p-value for APH1A: 0.25585266496220693
# Univariate CoxPH p-value for APLNR: 0.9825015005221802
# Univariate CoxPH p-value for APLP1: 0.48684426140201664
# Univariate CoxPH p-value for APLP2: 0.1978047615809632
# Univariate CoxPH p-value for APOA1: 0.021763301128738304
# Univariate CoxPH p-value for APOA4: 0.2930081156981787
# Univariate CoxPH p-value for APOBEC3F: 0.7224957212903129
# Univariate CoxPH p-value for APOBEC3G: 0.8906925237780323
# Univariate CoxPH p-value for APOC1: 0.009069565705852193
# Univariate CoxPH p-value for APOC2: 0.5768969671054114
# Univariate CoxPH p-value for APOC3: 0.39139793235253695
# Univariate CoxPH p-value for APOD: 0.042502931589222366
# Univariate CoxPH p-value for APOE: 0.027926742291808863
# Univariate CoxPH p-value for APOH: 0.1784309404404478
# Univariate CoxPH p-value for APOL6: 0.009990819658033398
# Univariate CoxPH p-value for APOM: 0.0003304134527136334
# Univariate CoxPH p-value for APP: 0.918639198786773
# Univariate CoxPH p-value for APPBP2: 0.0480005748521404
# Univariate CoxPH p-value for APRT: 0.0003100161082968296
# Univariate CoxPH p-value for AQP3: 0.8115344726912377
# Univariate CoxPH p-value for AQP7: 0.1467206164201534
# Univariate CoxPH p-value for AQP9: 0.8208007546617189
# Univariate CoxPH p-value for AR: 0.9168181860793423
# Univariate CoxPH p-value for ARAF: 0.865490474116089
# Univariate CoxPH p-value for ARAP3: 0.7858482415182608
# Univariate CoxPH p-value for ARCN1: 0.040651884313035284
# Univariate CoxPH p-value for AREG: 0.00714755614364633
# Univariate CoxPH p-value for ARF1: 0.1340099058043791
# Univariate CoxPH p-value for ARF6: 0.17050300324933398
# Univariate CoxPH p-value for ARFGAP1: 0.34639422226487915
# Univariate CoxPH p-value for ARFGAP3: 0.7771484580595451
# Univariate CoxPH p-value for ARFGEF1: 0.0008753593376709804
# Univariate CoxPH p-value for ARFGEF2: 0.005837547779293308
# Univariate CoxPH p-value for ARFIP1: 0.2867415561902652
# Univariate CoxPH p-value for ARFIP2: 0.03357143608960921
# Univariate CoxPH p-value for ARG1: 0.70161333143557
# Univariate CoxPH p-value for ARG2: 0.012159385914193577
# Univariate CoxPH p-value for ARHGAP10: 0.5632126294590625
# Univariate CoxPH p-value for ARHGAP27: 0.007387603020815611
# Univariate CoxPH p-value for ARHGAP29: 0.7475128299250953
# Univariate CoxPH p-value for ARHGAP4: 0.6563656827695685
# Univariate CoxPH p-value for ARHGAP5: 0.03580713423957642
# Univariate CoxPH p-value for ARHGDIA: 0.5734548532935695
# Univariate CoxPH p-value for ARHGDIG: 0.5216491218265016
# Univariate CoxPH p-value for ARHGEF11: 0.14707496292547062
# Univariate CoxPH p-value for ARHGEF12: 0.0034234280115433883
# Univariate CoxPH p-value for ARHGEF2: 0.11336267910765922
# Univariate CoxPH p-value for ARHGEF3: 0.43130543694199097
# Univariate CoxPH p-value for ARHGEF6: 0.17818971687556434
# Univariate CoxPH p-value for ARHGEF7: 0.0004304761010740127
# Univariate CoxPH p-value for ARHGEF9: 0.6846025072888491
# Univariate CoxPH p-value for ARID4A: 0.020392951953856663
# Univariate CoxPH p-value for ARID4B: 6.655797757444206e-05
# Univariate CoxPH p-value for ARID5B: 0.38326762675592163
# Univariate CoxPH p-value for ARL2BP: 0.0016763225042621557
# Univariate CoxPH p-value for ARL3: 0.0007489883339428428
# Univariate CoxPH p-value for ARL4A: 0.023334347301045718
# Univariate CoxPH p-value for ARL6IP1: 0.18292399024679637
# Univariate CoxPH p-value for ARL8A: 0.14126049567266188
# Univariate CoxPH p-value for ARPC2: 0.12968314775790304
# Univariate CoxPH p-value for ARPC3: 0.021971587802993416
# Univariate CoxPH p-value for ARPC5L: 0.4408602652151282
# Univariate CoxPH p-value for ARPP19: 0.9545178059040589
# Univariate CoxPH p-value for ARPP21: 0.15233322792454937
# Univariate CoxPH p-value for ARRB1: 0.04097423042518065
# Univariate CoxPH p-value for ARRB2: 0.02931580855599527
# Univariate CoxPH p-value for ART3: 0.9600322144687576
# Univariate CoxPH p-value for ARTN: 0.8695346905860891
# Univariate CoxPH p-value for ASB13: 0.3312867534412951
# Univariate CoxPH p-value for ASB7: 0.630530617973554
# Univariate CoxPH p-value for ASCL1: 0.9982868458948744
# Univariate CoxPH p-value for ASF1A: 5.582864387535712e-07
# Univariate CoxPH p-value for ASF1B: 0.43722714960445974
# Univariate CoxPH p-value for ASL: 0.029907550729811612
# Univariate CoxPH p-value for ASNS: 0.418967402429708
# Univariate CoxPH p-value for ASS1: 0.5465858941511968
# Univariate CoxPH p-value for ATAD2: 0.023789889888915502
# Univariate CoxPH p-value for ATF1: 0.757316825356836
# Univariate CoxPH p-value for ATF3: 0.8981616347901922
# Univariate CoxPH p-value for ATF4: 0.32954890138956544
# Univariate CoxPH p-value for ATF5: 0.42555377656500004
# Univariate CoxPH p-value for ATF6: 0.030414722880504865
# Univariate CoxPH p-value for ATG10: 0.012719853426378701
# Univariate CoxPH p-value for ATG4A: 0.2714807960555223
# Univariate CoxPH p-value for ATG4B: 0.9950418632553679
# Univariate CoxPH p-value for ATL2: 0.9825504564273059
# Univariate CoxPH p-value for ATOH8: 0.6853194949127435
# Univariate CoxPH p-value for ATOX1: 2.6954206773580296e-05
# Univariate CoxPH p-value for ATP1A1: 0.41177327193777113
# Univariate CoxPH p-value for ATP1A3: 0.041985870887179595
# Univariate CoxPH p-value for ATP1B1: 0.6179165413478056
# Univariate CoxPH p-value for ATP1B3: 0.09678118702922017
# Univariate CoxPH p-value for ATP2A1: 0.04809155435492335
# Univariate CoxPH p-value for ATP2A2: 0.00195424549255615
# Univariate CoxPH p-value for ATP2B1: 0.732997727822692
# Univariate CoxPH p-value for ATP2B4: 0.008906522847557248
# Univariate CoxPH p-value for ATP2C1: 0.5297164777760945
# Univariate CoxPH p-value for ATP4A: 0.4735379445353286
# Univariate CoxPH p-value for ATP6AP1: 0.038115268252135424
# Univariate CoxPH p-value for ATP6V0A1: 0.3052491673077252
# Univariate CoxPH p-value for ATP6V0A4: 0.3507875147287426
# Univariate CoxPH p-value for ATP6V0B: 5.158452733914507e-06
# Univariate CoxPH p-value for ATP6V0C: 0.00019297115466954454
# Univariate CoxPH p-value for ATP6V0D1: 0.00022566184933398164
# Univariate CoxPH p-value for ATP6V0E1: 0.004289260087473612
# Univariate CoxPH p-value for ATP6V1B1: 0.44363237499162544
# Univariate CoxPH p-value for ATP6V1C1: 0.05259524974540499
# Univariate CoxPH p-value for ATP6V1D: 0.029709278932625982
# Univariate CoxPH p-value for ATP6V1E1: 6.74035725371211e-05
# Univariate CoxPH p-value for ATP6V1F: 0.00025905995766402345
# Univariate CoxPH p-value for ATP6V1G1: 0.0033320210631440517
# Univariate CoxPH p-value for ATP6V1H: 0.33511869350986156
# Univariate CoxPH p-value for ATP7A: 0.8281637012219809
# Univariate CoxPH p-value for ATP8B1: 0.444526088056463
# Univariate CoxPH p-value for ATRN: 0.006225980816439258
# Univariate CoxPH p-value for ATRX: 0.008088338051783477
# Univariate CoxPH p-value for ATXN1: 0.005902620789947348
# Univariate CoxPH p-value for ATXN2: 0.00016474346022467395
# Univariate CoxPH p-value for AUH: 0.9341956342168422
# Univariate CoxPH p-value for AURKA: 0.2929950634502999
# Univariate CoxPH p-value for AURKB: 0.1928299102468027
# Univariate CoxPH p-value for AUTS2: 0.7930988324468343
# Univariate CoxPH p-value for AVL9: 0.0022051992191383383
# Univariate CoxPH p-value for AVPR1A: 0.650520266898567
# Univariate CoxPH p-value for AXIN1: 0.1386882925487144
# Univariate CoxPH p-value for AXIN2: 0.4450804374035028
# Univariate CoxPH p-value for AXL: 0.1400418122107127
# Univariate CoxPH p-value for AZGP1: 0.035245494883715034
# Univariate CoxPH p-value for B2M: 0.41665524647080354
# Univariate CoxPH p-value for B3GALT6: 0.8618724505546729
# Univariate CoxPH p-value for B3GAT1: 0.02939814783949961
# Univariate CoxPH p-value for B3GAT3: 0.3246380048258887
# Univariate CoxPH p-value for B3GNT3: 0.16798259893428016
# Univariate CoxPH p-value for B4GALNT2: 0.4525095682497725
# Univariate CoxPH p-value for B4GALT1: 0.3643258015355786
# Univariate CoxPH p-value for B4GALT2: 0.850578438394311
# Univariate CoxPH p-value for B4GALT4: 0.09010247444902328
# Univariate CoxPH p-value for B4GALT5: 0.039973747769115026
# Univariate CoxPH p-value for B4GALT7: 0.12832210860009594
# Univariate CoxPH p-value for BACH1: 0.43782885917112646
# Univariate CoxPH p-value for BAG1: 0.08030110516559273
# Univariate CoxPH p-value for BAG3: 0.03712443901107345
# Univariate CoxPH p-value for BAIAP2: 0.21165606411507576
# Univariate CoxPH p-value for BAK1: 0.947358592425508
# Univariate CoxPH p-value for BANK1: 0.13388907225228044
# Univariate CoxPH p-value for BARD1: 0.02086029213805335
# Univariate CoxPH p-value for BASP1: 0.5430320607511581
# Univariate CoxPH p-value for BATF: 0.46235829901224834
# Univariate CoxPH p-value for BATF2: 0.0785677404057115
# Univariate CoxPH p-value for BATF3: 0.2683791702116038
# Univariate CoxPH p-value for BAX: 0.1254081839495744
# Univariate CoxPH p-value for BAZ2A: 3.5838677873674643e-06
# Univariate CoxPH p-value for BBOX1: 0.49678552233852946
# Univariate CoxPH p-value for BCAM: 0.4738876159441675
# Univariate CoxPH p-value for BCAN: 0.4333527693084671
# Univariate CoxPH p-value for BCAP31: 0.006105051199828969
# Univariate CoxPH p-value for BCAR1: 0.6471629600112294
# Univariate CoxPH p-value for BCAR3: 0.4936013738933016
# Univariate CoxPH p-value for BCAT1: 0.014185676514943343
# Univariate CoxPH p-value for BCKDHA: 0.2379391854005935
# Univariate CoxPH p-value for BCKDHB: 0.7211030793180675
# Univariate CoxPH p-value for BCL10: 0.30779603668610195
# Univariate CoxPH p-value for BCL11B: 0.0034919132496972313
# Univariate CoxPH p-value for BCL2: 0.14423562831207684
# Univariate CoxPH p-value for BCL2A1: 0.20142014937340197
# Univariate CoxPH p-value for BCL2L1: 0.5922275189572751
# Univariate CoxPH p-value for BCL2L10: 0.7847206509756104
# Univariate CoxPH p-value for BCL2L11: 0.00200495098952814
# Univariate CoxPH p-value for BCL2L13: 0.3120524466532952
# Univariate CoxPH p-value for BCL2L2: 0.079466923287239
# Univariate CoxPH p-value for BCL3: 0.6381713272760441
# Univariate CoxPH p-value for BCL6: 0.24852716435045585
# Univariate CoxPH p-value for BCR: 0.04170402269846408
# Univariate CoxPH p-value for BDH2: 0.00023591864276233988
# Univariate CoxPH p-value for BDKRB1: 0.9289152686603586
# Univariate CoxPH p-value for BDKRB2: 0.5940472523131571
# Univariate CoxPH p-value for BDNF: 0.38590122263807225
# Univariate CoxPH p-value for BEST1: 0.6606189160711489
# Univariate CoxPH p-value for BET1: 0.6459010761470393
# Univariate CoxPH p-value for BGN: 0.14896727907591836
# Univariate CoxPH p-value for BHLHE40: 0.13381493264456684
# Univariate CoxPH p-value for BID: 0.2834906427702261
# Univariate CoxPH p-value for BIK: 0.6490394598242668
# Univariate CoxPH p-value for BIN1: 0.5667662662218127
# Univariate CoxPH p-value for BIRC2: 0.012982527447546266
# Univariate CoxPH p-value for BIRC3: 0.004896084946459501
# Univariate CoxPH p-value for BIRC5: 0.3801744728195904
# Univariate CoxPH p-value for BLCAP: 0.26331803851212804
# Univariate CoxPH p-value for BLVRA: 0.0054876870519319195
# Univariate CoxPH p-value for BLVRB: 0.0002512072876755391
# Univariate CoxPH p-value for BMF: 0.05002774273352744
# Univariate CoxPH p-value for BMP1: 0.12527894126344943
# Univariate CoxPH p-value for BMP2: 0.6778428980852245
# Univariate CoxPH p-value for BMP2K: 0.005425310504524084
# Univariate CoxPH p-value for BMP6: 0.5880313259949259
# Univariate CoxPH p-value for BMPR1A: 0.07596749005509347
# Univariate CoxPH p-value for BMPR1B: 0.6631256450117473
# Univariate CoxPH p-value for BMPR2: 0.8679209546174287
# Univariate CoxPH p-value for BNIP3: 0.7442640256549324
# Univariate CoxPH p-value for BNIP3L: 0.019268912505604203
# Univariate CoxPH p-value for BOLA2: 0.00200278051344356
# Univariate CoxPH p-value for BPGM: 0.1748513525791901
# Univariate CoxPH p-value for BPHL: 0.15225884418505456
# Univariate CoxPH p-value for BPNT1: 0.4151888367200236
# Univariate CoxPH p-value for BRAF: 4.229182425434512e-06
# Univariate CoxPH p-value for BRCA1: 0.012727899625353712
# Univariate CoxPH p-value for BRCA2: 0.000145900755316662
# Univariate CoxPH p-value for BRDT: 0.8643150278011832
# Univariate CoxPH p-value for BRF2: 0.03940341412812627
# Univariate CoxPH p-value for BRMS1L: 0.18320769618631957
# Univariate CoxPH p-value for BRPF3: 1.0715150669977363e-06
# Univariate CoxPH p-value for BRS3: 0.5039064918431475
# Univariate CoxPH p-value for BSG: 0.0020315557352688965
# Univariate CoxPH p-value for BST2: 0.5046274529465131
# Univariate CoxPH p-value for BTBD3: 0.0979783321275524
# Univariate CoxPH p-value for BTC: 0.6339311015118497
# Univariate CoxPH p-value for BTG1: 0.049091061391367444
# Univariate CoxPH p-value for BTG2: 0.7255534658693826
# Univariate CoxPH p-value for BTG3: 0.20340520191065178
# Univariate CoxPH p-value for BTRC: 0.005058809429633035
# Univariate CoxPH p-value for BUB1: 0.06934895143175393
# Univariate CoxPH p-value for BUB1B: 0.09720335234356495
# Univariate CoxPH p-value for BUB3: 0.8309218638753151
# Univariate CoxPH p-value for BYSL: 0.8427923934864664
# Univariate CoxPH p-value for C1QA: 0.6616853584325285
# Univariate CoxPH p-value for C1QBP: 0.0012769091943390764
# Univariate CoxPH p-value for C1QC: 0.7608223821251155
# Univariate CoxPH p-value for C1R: 0.08342404228815556
# Univariate CoxPH p-value for C1S: 0.2704628286199089
# Univariate CoxPH p-value for C2: 0.09152406937988761
# Univariate CoxPH p-value for C3: 0.08802831415535135
# Univariate CoxPH p-value for C3AR1: 0.29424695951988356
# Univariate CoxPH p-value for C4BPB: 0.6775001605347873
# Univariate CoxPH p-value for C5: 0.030849240460619286
# Univariate CoxPH p-value for C5AR1: 0.6922946142347988
# Univariate CoxPH p-value for C8A: 0.5364406630115435
# Univariate CoxPH p-value for C8B: 0.05345719957832818
# Univariate CoxPH p-value for C8G: 0.34887001501488824
# Univariate CoxPH p-value for C9: 0.48372557990353393
# Univariate CoxPH p-value for CA1: 0.25122983782775704
# Univariate CoxPH p-value for CA12: 0.39714072025342706
# Univariate CoxPH p-value for CA2: 0.6010717100785424
# Univariate CoxPH p-value for CA4: 0.15888950584934003
# Univariate CoxPH p-value for CA6: 0.5968083962666282
# Univariate CoxPH p-value for CAB39: 0.0990411867297764
# Univariate CoxPH p-value for CAB39L: 0.002213341862467204
# Univariate CoxPH p-value for CACNA1A: 0.5295963178418113
# Univariate CoxPH p-value for CACNA1B: 0.3273521090933736
# Univariate CoxPH p-value for CACNA1F: 0.1311928337285841
# Univariate CoxPH p-value for CACNA1H: 0.74171755368979
# Univariate CoxPH p-value for CACNA2D2: 0.5799527026917791
# Univariate CoxPH p-value for CACNG1: 0.9758904936215336
# Univariate CoxPH p-value for CACYBP: 0.06320793016243899
# Univariate CoxPH p-value for CAD: 0.0064646907929320875
# Univariate CoxPH p-value for CADM1: 0.7026893016738316
# Univariate CoxPH p-value for CADM2: 0.5484114755313957
# Univariate CoxPH p-value for CADM3: 0.5764585847927883
# Univariate CoxPH p-value for CALB2: 0.5310926951680042
# Univariate CoxPH p-value for CALCB: 0.6743779128371976
# Univariate CoxPH p-value for CALCR: 0.09933737841496247
# Univariate CoxPH p-value for CALCRL: 0.5129718592869581
# Univariate CoxPH p-value for CALD1: 0.6270723185178506
# Univariate CoxPH p-value for CALM1: 0.00048413216098122414
# Univariate CoxPH p-value for CALM3: 0.31094739324148574
# Univariate CoxPH p-value for CALML5: 0.22761377016807605
# Univariate CoxPH p-value for CALR: 0.17529579634157103
# Univariate CoxPH p-value for CALU: 0.06050938507830415
# Univariate CoxPH p-value for CAMK1D: 0.3855168573463418
# Univariate CoxPH p-value for CAMK2B: 0.9621064610399691
# Univariate CoxPH p-value for CAMK4: 0.598797032610615
# Univariate CoxPH p-value for CAMKK2: 0.029010559014686847
# Univariate CoxPH p-value for CANT1: 0.0007500367094564489
# Univariate CoxPH p-value for CANX: 0.7729294207082661
# Univariate CoxPH p-value for CAP1: 0.2816919320927639
# Univariate CoxPH p-value for CAP2: 0.5963462506523409
# Univariate CoxPH p-value for CAPG: 0.020615576756261005
# Univariate CoxPH p-value for CAPN2: 0.05613440691248542
# Univariate CoxPH p-value for CAPN3: 0.17740027157061705
# Univariate CoxPH p-value for CAPN5: 0.32189589170399435
# Univariate CoxPH p-value for CAPN9: 0.5788317082563934
# Univariate CoxPH p-value for CAPZB: 0.05425079017957919
# Univariate CoxPH p-value for CARTPT: 0.8062031515291981
# Univariate CoxPH p-value for CASP1: 0.9812932131854558
# Univariate CoxPH p-value for CASP10: 0.12517932072685953
# Univariate CoxPH p-value for CASP2: 0.0007190968884661252
# Univariate CoxPH p-value for CASP3: 0.1676058926053423
# Univariate CoxPH p-value for CASP4: 0.8051971373253279
# Univariate CoxPH p-value for CASP5: 0.7387733771085362
# Univariate CoxPH p-value for CASP6: 0.712921095623752
# Univariate CoxPH p-value for CASP7: 0.587290554614663
# Univariate CoxPH p-value for CASP8: 0.9682403160504616
# Univariate CoxPH p-value for CASP8AP2: 0.02666709793017527
# Univariate CoxPH p-value for CASP9: 0.009146169935031045
# Univariate CoxPH p-value for CASQ1: 0.6727256465239995
# Univariate CoxPH p-value for CASQ2: 0.14320741889785865
# Univariate CoxPH p-value for CAST: 0.21244957572870596
# Univariate CoxPH p-value for CAT: 0.05762518573925887
# Univariate CoxPH p-value for CAV1: 0.5197033444261321
# Univariate CoxPH p-value for CAV2: 0.45828706750274817
# Univariate CoxPH p-value for CAV3: 0.18885578890539156
# Univariate CoxPH p-value for CBFA2T3: 0.9897035515474455
# Univariate CoxPH p-value for CBL: 0.0006167827712039374
# Univariate CoxPH p-value for CBLB: 0.000503200746905747
# Univariate CoxPH p-value for CBR1: 0.007867414237755669
# Univariate CoxPH p-value for CBR3: 1.0917181422389778e-05
# Univariate CoxPH p-value for CBR4: 0.7072574596808618
# Univariate CoxPH p-value for CBS: 0.22222195300774525
# Univariate CoxPH p-value for CBX1: 0.40795437469043205
# Univariate CoxPH p-value for CBX3: 0.7739060088104353
# Univariate CoxPH p-value for CBX5: 0.16101741926036114
# Univariate CoxPH p-value for CBX8: 0.8717713460977004
# Univariate CoxPH p-value for CCDC106: 0.3235764682018945
# Univariate CoxPH p-value for CCDC28A: 0.10596205015951632
# Univariate CoxPH p-value for CCDC88A: 0.05705644467946703
# Univariate CoxPH p-value for CCL11: 0.650093554532335
# Univariate CoxPH p-value for CCL13: 0.5483248840966559
# Univariate CoxPH p-value for CCL17: 0.052392636803275355
# Univariate CoxPH p-value for CCL19: 0.6202169764633829
# Univariate CoxPH p-value for CCL2: 0.2411591079159118
# Univariate CoxPH p-value for CCL20: 0.3019360727254954
# Univariate CoxPH p-value for CCL22: 0.03368117334195315
# Univariate CoxPH p-value for CCL24: 0.10243129498132614
# Univariate CoxPH p-value for CCL25: 0.1721188167995525
# Univariate CoxPH p-value for CCL4: 0.8958883034785537
# Univariate CoxPH p-value for CCL5: 0.42499272050746106
# Univariate CoxPH p-value for CCL7: 0.771111640412329
# Univariate CoxPH p-value for CCNA1: 0.08489416079357306
# Univariate CoxPH p-value for CCNA2: 0.24390845223098034
# Univariate CoxPH p-value for CCNB2: 0.15667122098882055
# Univariate CoxPH p-value for CCND1: 0.0013590898923503628
# Univariate CoxPH p-value for CCND2: 0.386229150393812
# Univariate CoxPH p-value for CCND3: 0.000369438598305927
# Univariate CoxPH p-value for CCNE1: 0.32930618634435943
# Univariate CoxPH p-value for CCNF: 0.04626995391854654
# Univariate CoxPH p-value for CCNG1: 0.08014196425894836
# Univariate CoxPH p-value for CCNG2: 0.4227743473443618
# Univariate CoxPH p-value for CCNK: 0.25613613984816386
# Univariate CoxPH p-value for CCNL1: 0.01592905980456548
# Univariate CoxPH p-value for CCNT1: 1.4869220042384886e-05
# Univariate CoxPH p-value for CCR1: 0.9468669625790088
# Univariate CoxPH p-value for CCR2: 0.2565469421238414
# Univariate CoxPH p-value for CCR4: 0.0001606771641621717
# Univariate CoxPH p-value for CCR5: 0.1045491331088851
# Univariate CoxPH p-value for CCR7: 0.7318842295562533
# Univariate CoxPH p-value for CCR8: 1.743662252482031e-05
# Univariate CoxPH p-value for CCRL2: 0.9332013391927676
# Univariate CoxPH p-value for CCT2: 0.042740457467781906
# Univariate CoxPH p-value for CCT3: 0.7998398652782093
# Univariate CoxPH p-value for CCT4: 0.3373960382689781
# Univariate CoxPH p-value for CCT5: 0.8847124285443766
# Univariate CoxPH p-value for CCT6B: 0.164898160657674
# Univariate CoxPH p-value for CCT7: 0.049844993676867726
# Univariate CoxPH p-value for CD14: 0.4694728748991136
# Univariate CoxPH p-value for CD151: 0.012567334643261518
# Univariate CoxPH p-value for CD160: 0.7936899978249777
# Univariate CoxPH p-value for CD1D: 0.7545967704758216
# Univariate CoxPH p-value for CD2: 0.41306906177744873
# Univariate CoxPH p-value for CD207: 0.6385473339125707
# Univariate CoxPH p-value for CD209: 6.615918340036037e-05
# Univariate CoxPH p-value for CD247: 0.5822350286624438
# Univariate CoxPH p-value for CD274: 0.014231214751263743
# Univariate CoxPH p-value for CD276: 0.08295922188917339
# Univariate CoxPH p-value for CD28: 0.011492457963685998
# Univariate CoxPH p-value for CD2AP: 7.085019938646506e-06
# Univariate CoxPH p-value for CD302: 0.056236336064811224
# Univariate CoxPH p-value for CD34: 0.9291832493467345
# Univariate CoxPH p-value for CD36: 0.5576855111007225
# Univariate CoxPH p-value for CD37: 0.8081828234408049
# Univariate CoxPH p-value for CD38: 0.8740290899621816
# Univariate CoxPH p-value for CD3D: 0.7569271405146581
# Univariate CoxPH p-value for CD3E: 0.4794637895600681
# Univariate CoxPH p-value for CD3G: 0.08807697457810025
# Univariate CoxPH p-value for CD4: 0.41941686364359776
# Univariate CoxPH p-value for CD40: 0.33342222413623124
# Univariate CoxPH p-value for CD40LG: 0.3467128407672785
# Univariate CoxPH p-value for CD44: 0.5433647277054887
# Univariate CoxPH p-value for CD46: 0.012347640170571847
# Univariate CoxPH p-value for CD47: 0.9256759422330879
# Univariate CoxPH p-value for CD48: 0.4012228973540367
# Univariate CoxPH p-value for CD55: 0.5639701352541551
# Univariate CoxPH p-value for CD59: 0.008915415446668825
# Univariate CoxPH p-value for CD63: 0.0009585694631868256
# Univariate CoxPH p-value for CD69: 0.30799855283288374
# Univariate CoxPH p-value for CD7: 0.6446546505353885
# Univariate CoxPH p-value for CD70: 0.29687128231723026
# Univariate CoxPH p-value for CD74: 0.225860259468038
# Univariate CoxPH p-value for CD79A: 0.8684740781788205
# Univariate CoxPH p-value for CD79B: 0.7326784425601831
# Univariate CoxPH p-value for CD80: 0.0074208952953622636
# Univariate CoxPH p-value for CD81: 0.002340553559319295
# Univariate CoxPH p-value for CD82: 0.5458694462860847
# Univariate CoxPH p-value for CD83: 0.5501734720530536
# Univariate CoxPH p-value for CD86: 0.40511651296229845
# Univariate CoxPH p-value for CD8A: 0.5046699537739203
# Univariate CoxPH p-value for CD8B: 0.3598170477898682
# Univariate CoxPH p-value for CD9: 0.06101528375928013
# Univariate CoxPH p-value for CD96: 0.09189198683461877
# Univariate CoxPH p-value for CD99: 0.01380653927862053
# Univariate CoxPH p-value for CDA: 0.8447947946067836
# Univariate CoxPH p-value for CDADC1: 0.010374019398036541
# Univariate CoxPH p-value for CDC14B: 0.5578406834202951
# Univariate CoxPH p-value for CDC20: 0.43290652047402733
# Univariate CoxPH p-value for CDC25A: 0.4579481214682767
# Univariate CoxPH p-value for CDC25B: 0.08831836920351571
# Univariate CoxPH p-value for CDC27: 0.6827495003639914
# Univariate CoxPH p-value for CDC34: 0.5822171442737254
# Univariate CoxPH p-value for CDC42: 0.0005957090253431521
# Univariate CoxPH p-value for CDC42BPA: 0.013336078093699437
# Univariate CoxPH p-value for CDC42EP1: 0.025796063337080136
# Univariate CoxPH p-value for CDC42EP2: 0.23669187662314162
# Univariate CoxPH p-value for CDC42EP4: 0.08796859599057574
# Univariate CoxPH p-value for CDC42SE2: 0.6217918268142292
# Univariate CoxPH p-value for CDC45: 0.09876206844936576
# Univariate CoxPH p-value for CDC5L: 0.02702462983079062
# Univariate CoxPH p-value for CDC6: 0.06990972863827634
# Univariate CoxPH p-value for CDC7: 0.03998561214592787
# Univariate CoxPH p-value for CDCA3: 0.2896781221733861
# Univariate CoxPH p-value for CDCA8: 0.3684850392060718
# Univariate CoxPH p-value for CDCP1: 0.4570874290362015
# Univariate CoxPH p-value for CDH1: 0.023519899661555547
# Univariate CoxPH p-value for CDH11: 0.17589485703043167
# Univariate CoxPH p-value for CDH13: 0.8305789064656109
# Univariate CoxPH p-value for CDH15: 0.7022316313313406
# Univariate CoxPH p-value for CDH16: 0.6946300170364788
# Univariate CoxPH p-value for CDH2: 0.2341539177560496
# Univariate CoxPH p-value for CDH3: 0.050161588771036006
# Univariate CoxPH p-value for CDH4: 0.7114403004113329
# Univariate CoxPH p-value for CDH6: 0.43550828050817547
# Univariate CoxPH p-value for CDH8: 0.4275624409134453
# Univariate CoxPH p-value for CDK1: 0.40112005912186965
# Univariate CoxPH p-value for CDK13: 1.2987403159167278e-06
# Univariate CoxPH p-value for CDK2: 0.8215365259170162
# Univariate CoxPH p-value for CDK4: 0.06024033695977558
# Univariate CoxPH p-value for CDK5R1: 0.001540950997837556
# Univariate CoxPH p-value for CDK5RAP2: 0.012257167905190484
# Univariate CoxPH p-value for CDK6: 0.9390312766517127
# Univariate CoxPH p-value for CDK7: 0.1485078882641249
# Univariate CoxPH p-value for CDK8: 0.14489550486805286
# Univariate CoxPH p-value for CDK9: 0.5283139864813715
# Univariate CoxPH p-value for CDKAL1: 0.6346520230492991
# Univariate CoxPH p-value for CDKN1A: 0.5775445920125015
# Univariate CoxPH p-value for CDKN1B: 0.6972798188366167
# Univariate CoxPH p-value for CDKN1C: 0.007561182304635594
# Univariate CoxPH p-value for CDKN2A: 0.8244506965891549
# Univariate CoxPH p-value for CDKN2AIP: 0.4701065393857168
# Univariate CoxPH p-value for CDKN2B: 0.7095339288449614
# Univariate CoxPH p-value for CDKN2C: 0.04482879913755976
# Univariate CoxPH p-value for CDKN2D: 0.022047048765714294
# Univariate CoxPH p-value for CDKN3: 0.513037612752828
# Univariate CoxPH p-value for CDO1: 0.8195506582284255
# Univariate CoxPH p-value for CDON: 0.2941749489890354
# Univariate CoxPH p-value for CDR2: 0.6998208282498188
# Univariate CoxPH p-value for CDSN: 0.1982059664099813
# Univariate CoxPH p-value for CEBPA: 0.046649963959933476
# Univariate CoxPH p-value for CEBPB: 0.06401882837276361
# Univariate CoxPH p-value for CEBPD: 0.40088758019658177
# Univariate CoxPH p-value for CEBPG: 0.15119085134899873
# Univariate CoxPH p-value for CEL: 0.29127603910755
# Univariate CoxPH p-value for CELF2: 0.2922019450967063
# Univariate CoxPH p-value for CELSR1: 0.0014337983945110098
# Univariate CoxPH p-value for CELSR2: 0.0047784954387903224
# Univariate CoxPH p-value for CENPA: 0.4336735083253497
# Univariate CoxPH p-value for CENPE: 0.013771429006885447
# Univariate CoxPH p-value for CENPF: 0.021023590519571526
# Univariate CoxPH p-value for CENPJ: 0.12901401824183195
# Univariate CoxPH p-value for CENPM: 0.5160520838166348
# Univariate CoxPH p-value for CENPN: 0.36151167858078725
# Univariate CoxPH p-value for CEP192: 8.108041674931265e-06
# Univariate CoxPH p-value for CEP250: 0.14884637821331057
# Univariate CoxPH p-value for CEP57: 0.6673860674823072
# Univariate CoxPH p-value for CEP72: 0.02806928003920551
# Univariate CoxPH p-value for CERCAM: 0.1623643766737327
# Univariate CoxPH p-value for CES1: 0.012921053230711126
# Univariate CoxPH p-value for CETN2: 0.011469035334664616
# Univariate CoxPH p-value for CFB: 0.2571557114785885
# Univariate CoxPH p-value for CFD: 0.032239430217975776
# Univariate CoxPH p-value for CFH: 0.10239895700938746
# Univariate CoxPH p-value for CFHR2: 0.6812963886294625
# Univariate CoxPH p-value for CFI: 0.5730026133007564
# Univariate CoxPH p-value for CFL1: 0.1056661576594159
# Univariate CoxPH p-value for CFLAR: 0.00012929011640551503
# Univariate CoxPH p-value for CFP: 0.1173771041082194
# Univariate CoxPH p-value for CFTR: 0.4587489189156556
# Univariate CoxPH p-value for CGRRF1: 0.00422792429654235
# Univariate CoxPH p-value for CH25H: 0.5805687572913618
# Univariate CoxPH p-value for CHAC1: 0.024176078165355257
# Univariate CoxPH p-value for CHAF1A: 0.009739664947861864
# Univariate CoxPH p-value for CHCHD10: 0.03019585331369219
# Univariate CoxPH p-value for CHEK1: 0.17629622709836515
# Univariate CoxPH p-value for CHEK2: 0.18706131155880062
# Univariate CoxPH p-value for CHFR: 0.2611618910664172
# Univariate CoxPH p-value for CHGA: 0.9255174851372047
# Univariate CoxPH p-value for CHKA: 0.58813774614709
# Univariate CoxPH p-value for CHMP1A: 0.0002913695521207693
# Univariate CoxPH p-value for CHPF: 0.9832367795320813
# Univariate CoxPH p-value for CHPF2: 0.32600773997470256
# Univariate CoxPH p-value for CHPT1: 0.0006971388535769835
# Univariate CoxPH p-value for CHRM4: 0.42426171764362597
# Univariate CoxPH p-value for CHRNA1: 0.477183217486293
# Univariate CoxPH p-value for CHRNA5: 0.7831428679406867
# Univariate CoxPH p-value for CHRNB1: 0.773368366174146
# Univariate CoxPH p-value for CHRNG: 0.010012985796504836
# Univariate CoxPH p-value for CHST1: 0.2551913928862607
# Univariate CoxPH p-value for CHST12: 0.06393591852518438
# Univariate CoxPH p-value for CHST2: 0.7253638030231142
# Univariate CoxPH p-value for CHST3: 1.0704194201773868e-05
# Univariate CoxPH p-value for CHST6: 0.5348067083271254
# Univariate CoxPH p-value for CHST8: 0.05853248296618347
# Univariate CoxPH p-value for CHUK: 0.5738349700511082
# Univariate CoxPH p-value for CIDEA: 0.6108882609763778
# Univariate CoxPH p-value for CIITA: 0.12480846071142156
# Univariate CoxPH p-value for CIR1: 0.0020668777041263804
# Univariate CoxPH p-value for CISH: 0.5776916435890684
# Univariate CoxPH p-value for CIT: 0.09884231263539955
# Univariate CoxPH p-value for CITED2: 0.09556835919201345
# Univariate CoxPH p-value for CKAP4: 0.2723947915654466
# Univariate CoxPH p-value for CKAP5: 0.0037460055415463604
# Univariate CoxPH p-value for CKB: 0.9055779140986498
# Univariate CoxPH p-value for CKM: 0.9449135222706949
# Univariate CoxPH p-value for CKMT2: 0.1834470525289197
# Univariate CoxPH p-value for CKS1B: 0.8020949746442991
# Univariate CoxPH p-value for CKS2: 0.22440256426768387
# Univariate CoxPH p-value for CLASP1: 0.02936084582133372
# Univariate CoxPH p-value for CLCA2: 0.5020420581781053
# Univariate CoxPH p-value for CLCF1: 0.01304327744987168
# Univariate CoxPH p-value for CLCN2: 0.26717687000007156
# Univariate CoxPH p-value for CLCN3: 0.20070090512724828
# Univariate CoxPH p-value for CLDN11: 0.9724579011855742
# Univariate CoxPH p-value for CLDN14: 0.4978762041391095
# Univariate CoxPH p-value for CLDN15: 0.12642059743900905
# Univariate CoxPH p-value for CLDN16: 0.9890210421111307
# Univariate CoxPH p-value for CLDN18: 0.7805627427519263
# Univariate CoxPH p-value for CLDN19: 0.9869036933005316
# Univariate CoxPH p-value for CLDN3: 0.2616524253531697
# Univariate CoxPH p-value for CLDN4: 0.7237248169798439
# Univariate CoxPH p-value for CLDN5: 0.01928229748019486
# Univariate CoxPH p-value for CLDN6: 0.5264536735519365
# Univariate CoxPH p-value for CLDN7: 0.9369641301052472
# Univariate CoxPH p-value for CLDN8: 0.2231821188920022
# Univariate CoxPH p-value for CLDN9: 0.5028641602882317
# Univariate CoxPH p-value for CLEC4A: 0.91795591735428
# Univariate CoxPH p-value for CLEC5A: 0.04958083552517985
# Univariate CoxPH p-value for CLGN: 0.07023695038047532
# Univariate CoxPH p-value for CLIC2: 0.027109577161905526
# Univariate CoxPH p-value for CLIC3: 0.06252984842390841
# Univariate CoxPH p-value for CLIP1: 0.002558421585306334
# Univariate CoxPH p-value for CLIP2: 0.17017396369517487
# Univariate CoxPH p-value for CLN5: 0.012460375613461066
# Univariate CoxPH p-value for CLN6: 0.02297198515853295
# Univariate CoxPH p-value for CLN8: 0.870160379484514
# Univariate CoxPH p-value for CLNS1A: 0.4582978631295085
# Univariate CoxPH p-value for CLP1: 0.09831377649134787
# Univariate CoxPH p-value for CLPB: 0.5305441798957804
# Univariate CoxPH p-value for CLPS: 0.5147114118182952
# Univariate CoxPH p-value for CLSTN3: 0.06722090526947201
# Univariate CoxPH p-value for CLTA: 0.000470277562537109
# Univariate CoxPH p-value for CLTB: 0.047822193250393184
# Univariate CoxPH p-value for CLTC: 0.0005016011739644835
# Univariate CoxPH p-value for CLU: 0.0040611755227554485
# Univariate CoxPH p-value for CLVS1: 0.7983664760232794
# Univariate CoxPH p-value for CMBL: 0.011798758821192822
# Univariate CoxPH p-value for CMKLR1: 0.061483336358545256
# Univariate CoxPH p-value for CMPK1: 0.22334527198348086
# Univariate CoxPH p-value for CMPK2: 0.6574973831173818
# Univariate CoxPH p-value for CNBP: 0.007777650901392836
# Univariate CoxPH p-value for CNDP2: 0.07055390680376387
# Univariate CoxPH p-value for CNIH2: 0.9766963935833213
# Univariate CoxPH p-value for CNN2: 0.9207835846006187
# Univariate CoxPH p-value for CNN3: 0.5925800180728569
# Univariate CoxPH p-value for CNOT2: 0.3961543116142128
# Univariate CoxPH p-value for CNOT4: 0.0012694092468634869
# Univariate CoxPH p-value for CNOT6: 0.21012966959266008
# Univariate CoxPH p-value for CNP: 0.8965711738033794
# Univariate CoxPH p-value for CNTFR: 0.5930712336766918
# Univariate CoxPH p-value for CNTN1: 0.188017586129069
# Univariate CoxPH p-value for CNTROB: 0.8871555333160451
# Univariate CoxPH p-value for COCH: 0.33005003694395707
# Univariate CoxPH p-value for COG2: 0.291176589668087
# Univariate CoxPH p-value for COIL: 0.5270226591677134
# Univariate CoxPH p-value for COL11A1: 0.033771888627216806
# Univariate CoxPH p-value for COL12A1: 0.022668481895507814
# Univariate CoxPH p-value for COL15A1: 0.05400222428061026
# Univariate CoxPH p-value for COL16A1: 0.02151495761224493
# Univariate CoxPH p-value for COL17A1: 0.10113182856141799
# Univariate CoxPH p-value for COL1A1: 0.00433207608917109
# Univariate CoxPH p-value for COL1A2: 0.002752052341020241
# Univariate CoxPH p-value for COL2A1: 0.32597912713271426
# Univariate CoxPH p-value for COL3A1: 0.004541192082929293
# Univariate CoxPH p-value for COL4A1: 0.04190606759965723
# Univariate CoxPH p-value for COL4A2: 0.04593425887112229
# Univariate CoxPH p-value for COL5A1: 0.0006855620608150639
# Univariate CoxPH p-value for COL5A2: 0.005975501949700881
# Univariate CoxPH p-value for COL5A3: 0.03142236095818504
# Univariate CoxPH p-value for COL6A1: 0.042917341959661216
# Univariate CoxPH p-value for COL6A2: 0.04192679773258178
# Univariate CoxPH p-value for COL6A3: 0.000856386446328502
# Univariate CoxPH p-value for COL7A1: 0.0765439395935041
# Univariate CoxPH p-value for COL8A2: 0.1973872572733596
# Univariate CoxPH p-value for COL9A1: 0.8186527131782294
# Univariate CoxPH p-value for COMP: 0.41565376939475773
# Univariate CoxPH p-value for COMT: 0.0014428500451548743
# Univariate CoxPH p-value for COPA: 0.33398062550565305
# Univariate CoxPH p-value for COPB1: 0.6946029923737491
# Univariate CoxPH p-value for COPB2: 0.2748522204988087
# Univariate CoxPH p-value for COPE: 0.0015897039568459434
# Univariate CoxPH p-value for COPS5: 0.02258428001946245
# Univariate CoxPH p-value for COPZ2: 0.13132114523068364
# Univariate CoxPH p-value for COQ3: 0.0059164960211500394
# Univariate CoxPH p-value for COQ5: 0.02030327604274765
# Univariate CoxPH p-value for COQ9: 0.002680785844579075
# Univariate CoxPH p-value for CORO1A: 0.6480819083631331
# Univariate CoxPH p-value for COX10: 0.4995637835376725
# Univariate CoxPH p-value for COX11: 0.12521291376542174
# Univariate CoxPH p-value for COX15: 0.028507122554691625
# Univariate CoxPH p-value for COX17: 5.5556672890800894e-05
# Univariate CoxPH p-value for COX4I1: 1.47999753511806e-08
# Univariate CoxPH p-value for COX5A: 0.0012699751697456652
# Univariate CoxPH p-value for COX5B: 3.447750437867005e-07
# Univariate CoxPH p-value for COX6A1: 0.0017882619439562866
# ...
# Univariate CoxPH p-value for TP53INP1: 0.01611434717997556
# Univariate CoxPH p-value for TP53INP2: 0.8926142284967113
# Univariate CoxPH p-value for TP63: 0.5811452928154652
# Univariate CoxPH p-value for TPBG: 0.09108475142849992
# Univariate CoxPH p-value for TPD52: 0.563417535237996
# Univariate CoxPH p-value for TPD52L1: 7.940729491132276e-05
# Univariate CoxPH p-value for TPI1: 0.2264345191781319
# Univariate CoxPH p-value for TPM1: 0.7456055312836796
# Univariate CoxPH p-value for TPM2: 0.7481578251313165
# Univariate CoxPH p-value for TPM3: 0.40753938957123703
# Univariate CoxPH p-value for TPM4: 0.5627394192240291
# Univariate CoxPH p-value for TPRKB: 0.0003736960334485941
# Univariate CoxPH p-value for TPSAB1: 0.7194075487947132
# Univariate CoxPH p-value for TPST1: 0.7035293267951324
# Univariate CoxPH p-value for TPST2: 0.26484859574674524
# Univariate CoxPH p-value for TPX2: 0.11175679263540812
# Univariate CoxPH p-value for TRA2B: 0.30573649663118574
# Univariate CoxPH p-value for TRAF1: 2.1263493609304553e-05
# Univariate CoxPH p-value for TRAF2: 0.01003873367121115
# Univariate CoxPH p-value for TRAF4: 0.25404387253529714
# Univariate CoxPH p-value for TRAFD1: 0.46317805000497003
# Univariate CoxPH p-value for TRAIP: 0.4295532112707723
# Univariate CoxPH p-value for TRAK2: 0.8495482565828197
# Univariate CoxPH p-value for TRAT1: 0.17954607816045534
# Univariate CoxPH p-value for TRIAP1: 0.009018606324615094
# Univariate CoxPH p-value for TRIB1: 0.1753048390025239
# Univariate CoxPH p-value for TRIB2: 0.8995399025069998
# Univariate CoxPH p-value for TRIB3: 0.044272453375767774
# Univariate CoxPH p-value for TRIM10: 0.5621098146792431
# Univariate CoxPH p-value for TRIM14: 0.003017439210059841
# Univariate CoxPH p-value for TRIM21: 0.13381244676456844
# Univariate CoxPH p-value for TRIM25: 0.07972358891877983
# Univariate CoxPH p-value for TRIM26: 0.42368226473678205
# Univariate CoxPH p-value for TRIM28: 0.42313564757175237
# Univariate CoxPH p-value for TRIM29: 0.755375528528849
# Univariate CoxPH p-value for TRIM33: 0.0005785449538718943
# Univariate CoxPH p-value for TRIM5: 0.026133252329641195
# Univariate CoxPH p-value for TRIM58: 0.1739439481974833
# Univariate CoxPH p-value for TRIO: 2.3268829323166337e-06
# Univariate CoxPH p-value for TRIP10: 0.11978663768132454
# Univariate CoxPH p-value for TRIP13: 0.3615761875849186
# Univariate CoxPH p-value for TRO: 0.08461060955293916
# Univariate CoxPH p-value for TROAP: 0.3512728260952528
# Univariate CoxPH p-value for TSC1: 1.6934173166663196e-05
# Univariate CoxPH p-value for TSC2: 0.044252903836272735
# Univariate CoxPH p-value for TSC22D1: 0.078505994606877
# Univariate CoxPH p-value for TSG101: 0.0013912303661718455
# Univariate CoxPH p-value for TSHB: 0.26826318889336825
# Univariate CoxPH p-value for TSKU: 0.2934141637158932
# Univariate CoxPH p-value for TSN: 0.031053402920749335
# Univariate CoxPH p-value for TSPAN1: 0.06244161501275808
# Univariate CoxPH p-value for TSPAN13: 0.10387393783740446
# Univariate CoxPH p-value for TSPAN4: 0.050467696764039206
# Univariate CoxPH p-value for TSPAN5: 0.01845628901831458
# Univariate CoxPH p-value for TSPAN7: 0.024186091725954924
# Univariate CoxPH p-value for TSPAN8: 0.08151848443721928
# Univariate CoxPH p-value for TSPO: 0.004820732910264564
# Univariate CoxPH p-value for TSPO2: 0.29682497357927046
# Univariate CoxPH p-value for TSPYL2: 0.786367897490152
# /Users/mcgoug01/miniconda3/envs/CoxKAN/lib/python3.13/site-packages/lifelines/utils/__init__.py:1100: ConvergenceWarning: Column(s) ['TSSK2'] have very low variance. This may harm convergence. 1) Are you using formula's? Did you mean to add '-1' to the end. 2) Try dropping this redundant column before fitting if convergence fails.
#
#   warnings.warn(dedent(warning_text), ConvergenceWarning)
# /Users/mcgoug01/miniconda3/envs/CoxKAN/lib/python3.13/site-packages/lifelines/utils/__init__.py:797: RuntimeWarning: invalid value encountered in divide
#   return (X - mean) / std
# Error fitting CoxPH model for TSSK2: Convergence halted due to matrix inversion problems. Suspicion is high collinearity. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-modelMatrix is singular.
# Univariate CoxPH p-value for TSSK2: inf
# Univariate CoxPH p-value for TST: 0.011263014961793598
# Univariate CoxPH p-value for TTC37: 0.08544453733189636
# Univariate CoxPH p-value for TTC39A: 0.2813468135135507
# Univariate CoxPH p-value for TTC39B: 0.4690092739430185
# Univariate CoxPH p-value for TTK: 0.16236843252793912
# Univariate CoxPH p-value for TTPA: 0.03204006779414318
# Univariate CoxPH p-value for TTR: 0.9816187188783811
# Univariate CoxPH p-value for TUBA3C: 0.863556294623483
# Univariate CoxPH p-value for TUBA4A: 0.7736522907383969
# Univariate CoxPH p-value for TUBB: 0.7675685341145884
# Univariate CoxPH p-value for TUBB2A: 0.2510577491129572
# Univariate CoxPH p-value for TUBB2B: 0.3663364403260352
# Univariate CoxPH p-value for TUBD1: 0.01911759577140577
# Univariate CoxPH p-value for TUBG1: 0.6446599489741505
# Univariate CoxPH p-value for TUBGCP2: 0.2649571238277341
# Univariate CoxPH p-value for TUBGCP3: 0.052882575473155904
# Univariate CoxPH p-value for TUBGCP5: 0.31539640946336966
# Univariate CoxPH p-value for TUBGCP6: 0.0023995505088444196
# Univariate CoxPH p-value for TUFM: 1.4079088459592861e-05
# Univariate CoxPH p-value for TULP2: 0.6094158894414772
# Univariate CoxPH p-value for TWSG1: 0.8923645758758264
# Univariate CoxPH p-value for TXN: 0.031011704378332092
# Univariate CoxPH p-value for TXNIP: 0.09962803750228309
# Univariate CoxPH p-value for TXNL4A: 0.00063030102393025
# Univariate CoxPH p-value for TXNRD1: 0.3355222404537597
# Univariate CoxPH p-value for TXNRD2: 0.15941183011285148
# Univariate CoxPH p-value for TYK2: 3.498729842959092e-05
# Univariate CoxPH p-value for TYMS: 0.009738960106777954
# Univariate CoxPH p-value for TYR: 0.004421211798472922
# Univariate CoxPH p-value for TYRO3: 0.05264477553009722
# Univariate CoxPH p-value for U2AF1: 0.011860480288559428
# Univariate CoxPH p-value for UAP1: 0.7042129335421479
# Univariate CoxPH p-value for UBA2: 0.870964016851317
# Univariate CoxPH p-value for UBA7: 0.5006318334827482
# Univariate CoxPH p-value for UBAC1: 0.1537019100883903
# Univariate CoxPH p-value for UBC: 0.08779166833050027
# Univariate CoxPH p-value for UBE2C: 0.32878662886594984
# Univariate CoxPH p-value for UBE2D1: 0.5040436229359454
# Univariate CoxPH p-value for UBE2D3: 0.010895435695155027
# Univariate CoxPH p-value for UBE2E1: 0.1653564679745565
# Univariate CoxPH p-value for UBE2I: 0.05085243753116912
# Univariate CoxPH p-value for UBE2J1: 0.43646137490042236
# Univariate CoxPH p-value for UBE2L3: 0.5123144707917205
# Univariate CoxPH p-value for UBE2L6: 0.36488392813846715
# Univariate CoxPH p-value for UBE2N: 0.010101386100953203
# Univariate CoxPH p-value for UBE2S: 0.5862288952852587
# Univariate CoxPH p-value for UBE2T: 0.23051232350206124
# Univariate CoxPH p-value for UBQLN1: 0.5342993843969017
# Univariate CoxPH p-value for UBR7: 0.4322168182571867
# Univariate CoxPH p-value for UCHL5: 0.5729998389968705
# Univariate CoxPH p-value for UCK1: 0.013160884795376611
# Univariate CoxPH p-value for UCK2: 0.5956509854359906
# Univariate CoxPH p-value for UCP2: 0.05110355397649162
# Univariate CoxPH p-value for UFM1: 0.04212813617650902
# Univariate CoxPH p-value for UGCG: 0.0019611379172145196
# Univariate CoxPH p-value for UGDH: 0.2219752892633074
# Univariate CoxPH p-value for UGP2: 0.2475125820233324
# Univariate CoxPH p-value for UMPS: 0.4799412226844768
# Univariate CoxPH p-value for UNC119: 0.9793827866041919
# Univariate CoxPH p-value for UNC13B: 0.39477019311279526
# Univariate CoxPH p-value for UNC5C: 0.021754933646050304
# Univariate CoxPH p-value for UNG: 0.5482079275283691
# Univariate CoxPH p-value for UPB1: 0.5341341693850356
# Univariate CoxPH p-value for UPF1: 0.022191426273150006
# Univariate CoxPH p-value for UPF3B: 0.03084770875050072
# Univariate CoxPH p-value for UPK3B: 0.2694321696397664
# Univariate CoxPH p-value for UPP1: 0.679446884095399
# Univariate CoxPH p-value for UQCR10: 0.01564276166834036
# Univariate CoxPH p-value for UQCR11: 0.00022303832827455443
# Univariate CoxPH p-value for UQCRB: 0.05409171751069693
# Univariate CoxPH p-value for UQCRC1: 9.311241737644911e-07
# Univariate CoxPH p-value for UQCRC2: 0.03273135836469575
# Univariate CoxPH p-value for UQCRFS1: 0.13481707840829293
# Univariate CoxPH p-value for UQCRH: 0.0412640596945959
# Univariate CoxPH p-value for UQCRQ: 5.043583718949051e-07
# Univariate CoxPH p-value for UROD: 9.101423278473262e-07
# Univariate CoxPH p-value for UROS: 0.00025985037634503657
# Univariate CoxPH p-value for USH1C: 0.34154994258499194
# Univariate CoxPH p-value for USO1: 0.046481806673085366
# Univariate CoxPH p-value for USP1: 0.30403413950421354
# Univariate CoxPH p-value for USP11: 0.1789091510112703
# Univariate CoxPH p-value for USP12: 0.032720176098845366
# Univariate CoxPH p-value for USP14: 0.21085483524639656
# Univariate CoxPH p-value for USP15: 0.4006109261347902
# Univariate CoxPH p-value for USP16: 0.9123458657701656
# Univariate CoxPH p-value for USP18: 0.807958724623896
# Univariate CoxPH p-value for USP8: 0.010701664922541135
# Univariate CoxPH p-value for UTP20: 9.752580544890361e-06
# Univariate CoxPH p-value for UXT: 3.731372524176244e-07
# Univariate CoxPH p-value for VAMP3: 0.03357456755665681
# Univariate CoxPH p-value for VAMP4: 0.10134381535676058
# Univariate CoxPH p-value for VAMP5: 0.1036294476114097
# Univariate CoxPH p-value for VAMP7: 0.09111909428019034
# Univariate CoxPH p-value for VAMP8: 0.002746606213872987
# Univariate CoxPH p-value for VAPA: 0.1606369719796873
# Univariate CoxPH p-value for VASP: 0.005547119603560543
# Univariate CoxPH p-value for VAV2: 2.2911346132146082e-05
# Univariate CoxPH p-value for VAV3: 0.7590305047656027
# Univariate CoxPH p-value for VBP1: 0.1384946114276203
# Univariate CoxPH p-value for VCAM1: 0.06874997513229988
# Univariate CoxPH p-value for VCAN: 0.0009580340671914209
# Univariate CoxPH p-value for VCL: 0.0519447385477584
# Univariate CoxPH p-value for VCPIP1: 0.6936843885918333
# Univariate CoxPH p-value for VDAC1: 0.7628467113212066
# Univariate CoxPH p-value for VDAC2: 0.03528852061406047
# Univariate CoxPH p-value for VDAC3: 0.03927245163637608
# Univariate CoxPH p-value for VDR: 0.031511932679614676
# Univariate CoxPH p-value for VEGFA: 0.0005474933182795179
# Univariate CoxPH p-value for VEGFB: 0.0003890242249142072
# Univariate CoxPH p-value for VEGFC: 0.8386804952787245
# Univariate CoxPH p-value for VEZF1: 0.027090809367287347
# Univariate CoxPH p-value for VHL: 0.00015844871388006444
# Univariate CoxPH p-value for VIM: 0.45889961601580176
# Univariate CoxPH p-value for VIP: 0.13579596393204624
# Univariate CoxPH p-value for VIPR1: 0.20542777512779478
# Univariate CoxPH p-value for VLDLR: 0.7966516549654792
# Univariate CoxPH p-value for VNN1: 0.6381991911152933
# Univariate CoxPH p-value for VPREB1: 0.4158997665433928
# Univariate CoxPH p-value for VPS28: 0.007200909045780443
# Univariate CoxPH p-value for VPS37B: 0.6219727111415683
# Univariate CoxPH p-value for VPS37D: 0.36039442534531696
# Univariate CoxPH p-value for VPS45: 0.6800532446813501
# Univariate CoxPH p-value for VPS4B: 0.7647346566102885
# Univariate CoxPH p-value for VTN: 0.8630049894432612
# Univariate CoxPH p-value for VWA5A: 0.09277984284635005
# Univariate CoxPH p-value for VWF: 0.6778291260448255
# Univariate CoxPH p-value for WAS: 0.7383631449564585
# Univariate CoxPH p-value for WASF1: 0.3202605290930764
# Univariate CoxPH p-value for WASF2: 0.16549922132291264
# Univariate CoxPH p-value for WASL: 0.11688506700360465
# Univariate CoxPH p-value for WDR1: 0.9580714786944075
# Univariate CoxPH p-value for WDR33: 0.00897649716950704
# Univariate CoxPH p-value for WDR37: 0.015780061917029665
# Univariate CoxPH p-value for WDR43: 0.12912826385322837
# Univariate CoxPH p-value for WDR74: 0.055018811308788565
# Univariate CoxPH p-value for WDR90: 0.026100217541736814
# Univariate CoxPH p-value for WEE1: 0.5193968183865734
# Univariate CoxPH p-value for WFS1: 0.2148482380944113
# Univariate CoxPH p-value for WIPI1: 0.07424283318871053
# Univariate CoxPH p-value for WIZ: 0.026556722821620256
# Univariate CoxPH p-value for WLS: 0.6729879127597974
# Univariate CoxPH p-value for WNK4: 0.13981169410364958
# Univariate CoxPH p-value for WNT1: 0.2723709399665547
# Univariate CoxPH p-value for WNT16: 0.012014407186100765
# Univariate CoxPH p-value for WNT2: 0.36122712251260525
# Univariate CoxPH p-value for WNT5A: 0.9104038361840938
# Univariate CoxPH p-value for WNT5B: 0.4920233462561018
# Univariate CoxPH p-value for WNT6: 0.7273078804383517
# Univariate CoxPH p-value for WNT7A: 0.6340582500680678
# Univariate CoxPH p-value for WRN: 0.2233767635354267
# Univariate CoxPH p-value for WSB1: 0.0005388447208185495
# Univariate CoxPH p-value for WWC1: 0.8944739609506245
# Univariate CoxPH p-value for WWP1: 0.0062248610615539424
# Univariate CoxPH p-value for WWTR1: 0.6793581537037404
# Univariate CoxPH p-value for XAF1: 0.018290374239971485
# Univariate CoxPH p-value for XBP1: 0.4338021169744364
# Univariate CoxPH p-value for XCL1: 0.18970016212949967
# Univariate CoxPH p-value for XDH: 0.27404014641462
# Univariate CoxPH p-value for XIAP: 0.07196554661044187
# Univariate CoxPH p-value for XIST: 0.9767410971066441
# Univariate CoxPH p-value for XK: 0.06985766805090322
# Univariate CoxPH p-value for XPC: 0.26944044548149587
# Univariate CoxPH p-value for XPNPEP1: 0.039061703348640134
# Univariate CoxPH p-value for XPO1: 0.032190726174154936
# Univariate CoxPH p-value for XPO7: 0.9062018962957413
# Univariate CoxPH p-value for XPOT: 0.5512512115445583
# Univariate CoxPH p-value for XRCC3: 0.2796651392661009
# Univariate CoxPH p-value for XRCC5: 0.07001346831882174
# Univariate CoxPH p-value for XRCC6: 0.30330756554892935
# Univariate CoxPH p-value for XYLT2: 0.02456890841886869
# Univariate CoxPH p-value for YBX2: 0.7166560037541216
# Univariate CoxPH p-value for YIF1A: 0.057281975597863515
# Univariate CoxPH p-value for YIPF6: 0.5055281119924661
# Univariate CoxPH p-value for YKT6: 0.6523893391327258
# Univariate CoxPH p-value for YPEL1: 0.033067093681804424
# Univariate CoxPH p-value for YPEL5: 0.001462836333431533
# Univariate CoxPH p-value for YRDC: 0.02130074397602219
# Univariate CoxPH p-value for YTHDC1: 0.033641449689000597
# Univariate CoxPH p-value for YWHAB: 0.010160301480572115
# Univariate CoxPH p-value for YWHAE: 7.988776526110821e-05
# Univariate CoxPH p-value for YWHAG: 0.16345359692189992
# Univariate CoxPH p-value for YWHAH: 0.29037552161449875
# Univariate CoxPH p-value for YWHAQ: 0.18841960858290976
# Univariate CoxPH p-value for YWHAZ: 0.13424612481482434
# Univariate CoxPH p-value for ZAP70: 0.016331866353217768
# Univariate CoxPH p-value for ZBP1: 0.029186694542514473
# Univariate CoxPH p-value for ZBTB10: 0.022455919156303166
# Univariate CoxPH p-value for ZBTB16: 0.3266815164116932
# Univariate CoxPH p-value for ZBTB17: 0.7240873622883606
# Univariate CoxPH p-value for ZC3H12A: 0.07800569439396499
# Univariate CoxPH p-value for ZC3H14: 0.3448235993758123
# Univariate CoxPH p-value for ZEB1: 0.06608544200383935
# Univariate CoxPH p-value for ZFP36: 0.671890260816639
# Univariate CoxPH p-value for ZFP36L1: 0.0014066135588370384
# Univariate CoxPH p-value for ZFPM2: 0.3461604858011439
# Univariate CoxPH p-value for ZMAT3: 0.33847893998116274
# Univariate CoxPH p-value for ZMIZ1: 0.01341910839320308
# Univariate CoxPH p-value for ZNF185: 0.47920160121888045
# Univariate CoxPH p-value for ZNF277: 0.07415154390871144
# Univariate CoxPH p-value for ZNF292: 0.007109702173331869
# Univariate CoxPH p-value for ZNF365: 0.26288669876834214
# Univariate CoxPH p-value for ZNF639: 0.14916494938839392
# Univariate CoxPH p-value for ZNF707: 0.011374841633197099
# Univariate CoxPH p-value for ZNFX1: 0.002319105593898392
# Univariate CoxPH p-value for ZNRF4: 0.3973124178872032
# Univariate CoxPH p-value for ZPBP: 0.42299824170706757
# Univariate CoxPH p-value for ZW10: 0.056162279877519344
# Univariate CoxPH p-value for ZWINT: 0.27247223954316546
# Univariate CoxPH p-value for ZYX: 0.27075090368117194
# Filtered genomics dataframe shape: (538, 1256)

# %%
import numpy as np
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
imp = IterativeImputer(max_iter=10, random_state=0)
# train a random forest regressor to impute missing values
imp.fit(filtered_genomics_df.drop(columns=['sample']))
imputed_genomics = imp.transform(filtered_genomics_df.drop(columns=['sample']))

# %%
# combine imputed_genomics with the sample column to create new df imputed_genomics_df
imputed_genomics_df = pd.DataFrame(imputed_genomics, columns=filtered_genomics_df.columns[1:])
imputed_genomics_df['sample'] = filtered_genomics_df['sample'].values
print(imputed_genomics_df.shape)
# check for multicollinearity in imputed_genomics_df
corr = imputed_genomics_df.corr(numeric_only=True).abs()
high_corr_pairs = (
    corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
         .stack()
         .loc[lambda s: s > 0.5]              # pick your own threshold
)

# for the highly correlated pairs, drop the one with the lower p-value
for col1, col2 in high_corr_pairs.index:
    #if not all of col1 and col2 are in imputed_genomics_df, skip
    if col1 not in imputed_genomics_df.columns or col2 not in imputed_genomics_df.columns:
        continue
        
    if correlations[col1] < correlations[col2]:
        imputed_genomics_df = imputed_genomics_df.drop(columns=[col2])
    else:
        imputed_genomics_df = imputed_genomics_df.drop(columns=[col1])
        
final_genomics_df = imputed_genomics_df.copy()
print(f"Final genomics dataframe shape: {final_genomics_df.shape}")
# Out:
# (538, 1256)
# Final genomics dataframe shape: (538, 432)

# %%
#split into test and train based on genomic_labels_train_df
train_df = final_genomics_df[final_genomics_df['sample'].isin(genomic_labels_train_df['case_id'])].copy()
test_df = final_genomics_df[final_genomics_df['sample'].isin(genomic_labels_test_df['case_id'])].copy()
print(f"Train dataframe shape: {train_df.shape}")
print(f"Test dataframe shape: {test_df.shape}")

# convert duration column to name 'duration', and event column to name 'event'
# in the event col, convert all values of 1 to 0, and all other values to 1
train_df.rename(columns={'dss_cr_survival_days': 'duration'}, inplace=True)
train_df.rename(columns={'dss_cr_censorship': 'event'}, inplace=True)
train_df['event'] = train_df['event'].replace({0:1,1:0})
test_df.rename(columns={'dss_cr_survival_days': 'duration'}, inplace=True)
test_df.rename(columns={'dss_cr_censorship': 'event'}, inplace=True)
test_df['event'] = test_df['event'].replace({0:1,1:0})

#for train and test, delete duplicate rowswith the same sample
train_df = train_df.drop_duplicates(subset=['sample'], keep='first')
test_df = test_df.drop_duplicates(subset=['sample'], keep='first')

# where -1 exists in the event column, remove row
train_df = train_df[train_df['event'] != -1]
test_df = test_df[test_df['event'] != -1]

#print test and train shapes
print(f"Train dataframe shape: {train_df.shape}")
print(f"Test dataframe shape: {test_df.shape}")

#make sample column the index
train_df.set_index('sample', inplace=True)
test_df.set_index('sample', inplace=True)

#print how many unique samples (in index) are in train_df and test_df
all_samples = train_df.index.tolist() + test_df.index.tolist()
print(f"Number of rows: {len(all_samples)}")
print(f"Number of unique samples: {len(set(all_samples))}")

#save to {name}_train.csv within folder CoxKAN/data/TCGA
train_df.to_csv(f'./TCGA/{name}_train.csv')
test_df.to_csv(f'./TCGA/{name}_test.csv')

print(f"Train dataframe shape: {train_df.shape}")
print(f"Test dataframe shape: {test_df.shape}")
# Out:
# Train dataframe shape: (422, 432)
# Test dataframe shape: (116, 432)
# Train dataframe shape: (289, 432)
# Test dataframe shape: (97, 432)
# Number of rows: 386
# Number of unique samples: 386
# Train dataframe shape: (289, 431)
# Test dataframe shape: (97, 431)
